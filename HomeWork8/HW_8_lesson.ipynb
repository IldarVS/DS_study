# %% [markdown]
# # Домашнее задание к 8 уроку
#
# **Дедлайн: 26.12.2020**

# %% [markdown]
# https://colab.research.google.com/drive/1cjF9-ozDqvi89gZ8otjuyE8uIGEb759X?usp=sharing

# %% [markdown]
# **ФОРМАТ ОТЧЕТНОСТИ:** pdf-файл с решенными задачами или же ноутбук с решенными задачи на языке Markdown.

# %% [markdown]
# # Часть 1. СЛАУ

# %% [markdown]
# __1.__ Решить систему уравнений методом Гаусса:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}=>$$умножим 1 строку на 2 и вычтем из второй первую строку и отнимем от 1 третью строку
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2 \\
# 0 & 1 & -1 & -5 \\
# 0 & 0 & -2 & 3 \\
# \end{matrix}\right |
# \begin{matrix}
# 0\\
# 2\\
# -4\\
# \end{matrix}
# \end{pmatrix}=>$$
# в последнем уравнении выразим $$x_{3} = x_{4}*3/2 -2$$
# тогда
# $$x_{2} = x_{4}*13/2$$
# $$x_{1} = -3 * x_{4} - 2$$
# таким образом количество решений бесконечно и зависит от $$x_{4}.$$
#
#
#
# __2.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases} =>$
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1 \\
# 0 & 13 & 11  \\
# 0 & -4 & 4  \\
# \end{matrix}\right |
# \begin{matrix}
# 4\\
# 59\\
# 4\\
# \end{matrix}
# \end{pmatrix}=>$
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1 \\
# 0 & 13 & 11  \\
# 0 & -1 & 1  \\
# \end{matrix}\right |
# \begin{matrix}
# 4\\
# 59\\
# 1\\
# \end{matrix}
# \end{pmatrix}=>$
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1 \\
# 0 & 13 & 11  \\
# 0 & 0 & 24  \\
# \end{matrix}\right |
# \begin{matrix}
# 4\\
# 59\\
# 72\\
# \end{matrix}
# \end{pmatrix}$
# $$$$
# в последнем уравнении получим $$x_{3} = 3$$
# тогда
# $$x_{2} = 2$$
# $$x_{1} = 1$$
# система линейных уравнений совместна и имеет 1 решение
#
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}=>$
# $\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6 \\
# 0 & 0 & 0  \\
# 0 & 0 & 0  \\
# \end{matrix}\right |
# \begin{matrix}
# -1\\
# 4\\
# -2\\
# \end{matrix}
# \end{pmatrix}$
# система линейных уравнений несовместна и не имеет решений
#
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}=>$
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5 \\
# 3 & 1 & -8  \\
# \end{matrix}\right |
# \begin{matrix}
# 4\\
# -2\\
# \end{matrix}
# \end{pmatrix}=>$
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5 \\
# 0 & 5 & 23  \\
# \end{matrix}\right |
# \begin{matrix}
# 4\\
# 14\\
# \end{matrix}
# \end{pmatrix}$
# $$x_{2} = x_{3}*23/5+14/5$$
# $$x_{1} = x_{3}*21/5 - 8/5$$
# система линейных уравнений совместна и  имеет бесконечное множество решений

# %% [markdown]
# # Часть 2. Дифференцируемость функций

# %% [markdown]
# Прочитайте краткую статью-обзор про **функции активации** в нейронных сетях. Дальше в курсе мы еще с Вами об этом поговорим, а сейчас достаточно знать какие функции активации нейронов существуют и определять дифференцируемы они или нет.
#
# Прочитайте следющие статьи:
# - https://www.machinelearningmastery.ru/complete-guide-of-activation-functions-34076e95d044/
# - https://missinglink.ai/guides/neural-network-concepts/7-types-neural-network-activation-functions-right/
#
# и выполните следующие задачи:

# %% [markdown]
# ## Задания

# %% [markdown]
# **1.** Для чего необходимо определять дифференцируемость/недефференцируемость функций активации в сетях?

# %% [markdown]
# **2.** Даны 1-6. Вычислите следующие характеристики:
#
# - производную функции
# - область значений
# - монотонность (монотонная или нет)
#
# 1. **Identity.** $f(x)=x$
# 2. **Binary step/Единичная ступенька**. $f(x)=\left\{\begin{array}{ll}0 & x<0 \\ 1 & x \geqslant 0\end{array}\right.$
# 3. **Hyperbolic tangent/Гиперболический тангенс**. $f(x)=\operatorname{th}(x)=\frac{\left(e^{x}-e^{-x}\right)}{\left(e^{x}+e^{-x}\right)}$
# 4. **ReLU**. $f(x)=\left\{\begin{array}{ll}0 & x<0 \\ x & x \geqslant 0\end{array}\right.$
# 5. **Softplus**. $f(x)=\ln \left(1+e^{x}\right)$
# 6. **Синусоида**. $f(x)=\sin (x)$
#
# Если функция дифференцируема на интервале  (a,b) и принадлежит к одному из четырехтипов (т.е. является возрастающей, строго возрастающей, убывающей или строго убывающей), то такая функция называется **монотонной** на данном интервале.
# <img src="https://github.com/ddvika/Data-Science-School-2020/blob/main/lecture_8/imgs/graphs.png?raw=true" height=400 />

# %% [markdown]
# Пример:
#
#  **0**. Дана функция **Softsign:** $f(x)=\frac{x}{1+|x|}$
#
#  1. Производная функции:
#  $f'(x)=(\frac{x}{1+|x|})' $
#
# - Воспользуемся правилом нахождения производной от частного:
#
#
# $$\frac{d}{d x}\left(\frac{u}{v}\right)=\frac{v \frac{d u}{d x}-u \frac{d v}{d x}}{v^{2}}$$
# Где $u = x$ и $ v = |x| + 1$.
#
# Следовательно, в нашем случае имеем:
#
# $\frac{d}{d x}\left(\frac{x}{1+|x|}\right)= \frac{(1+|x|)\left(\frac{d}{d x}(x)\right)-x\left(\frac{d}{d x}(1+|x|)\right)}{(1+|x|)^{2}}= \frac{1+|x|-x\left(\frac{d}{d x}(1+|x|)\right)}{(1+|x|)^{2}}=\frac{1+|x|-x\left(\frac{d}{d x}(|x|)+0\right)}{(1+|x|)^{2}} = $
#
# - Запишем $\frac{d}{d x}(|x|)$ след. образом  $\frac{d}{d x}(|x|)=\frac{d|u|}{d u} \frac{d u}{d x}$, где $u=x$, $\frac{d}{d u}(|u|)=\frac{u}{|u|}$
#
# $= \frac{1+|x|-\frac{x\left(\frac{d}{d x}(x)\right)}{|x|}}{(1+|x|)^{2}}= \frac{1+|x|-\frac{x^{2}\left(\frac{d}{d x}(x)\right)}{|x|}}{(1+|x|)^{2}}= \frac{1+|x|-1 \mid \frac{x^{2}}{|x|}}{(1+|x|)^{2}}= \frac{1}{(1+|x|)^{2}}$
#
# $$f'(x) = \frac{1}{(1+|x|)^{2}}$$
#
# **P.S.** Находить производную можно менее подробно!
#
# 2. Область значений функции:
#
# Знаменатель функции не должен быть равен 0:
#
# $|x|+1 \neq 0 \rightarrow x \in R$, то есть область значений - множество всех действительных чисел.
#
# Теперь найдем множество значений:
#
# Пусть $$\frac{x}{1+|x|} = a$$
# Решая уравнение $ \frac{x}{1+|x|}- a =0 $, получим $E = (-1,1)$
#
#
#
# $$E = (-1,1)$$
#
# 3. Определим моннотонна ли функция
#
# - построим график функции

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x/(1+abs(x))

a = np.arange(-100, 100)
plt.plot(a, f(a))
plt.title('Softsign')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# **Ответ: функция монотонна**

# %% [markdown]
# # Ваше решение тут

# %% [markdown]
# **P.S.** Находить производну можно менее подробно чем в примере! но нахождение каждого пункта решения и отрисовка графиков обязательна (С названием графика и подписью осей как в примере!).

# %% [markdown]
# 1. Производная функции:\
#  1.1 **Identity.** $f(x)=x$
#  - производная от a * x в степени 1 равно a
#
#  $f'(x)={1}$
#
# $x \in R$, то есть область значений - множество всех действительных чисел.
#
# Теперь найдем множество значений: так как  $f(x)=x$, то
# $E \in R$, то есть множество значений - множество всех действительных чисел.
#
#
#
#  1.2. **Binary step/Единичная ступенька**. $f(x)=\left\{\begin{array}{ll}0 & x<0 \\ 1 & x \geqslant 0\end{array}\right.$
#  - производная от числа равно 0
#
#  $f'(x)={0}$
#
# $x \in R$, то есть область значений - множество всех действительных чисел.
#
# Теперь найдем область определения: так как  $f(x)=0$ или $f(x)=1$, то
# $E \in $ {0,1}.
#
#
# 1.3. **Hyperbolic tangent/Гиперболический тангенс**. $f(x)=\operatorname{th}(x)=\frac{\left(e^{x}-e^{-x}\right)}{\left(e^{x}+e^{-x}\right)}$
#
# $=>\frac{\left(e^{x}-e^{-x}\right)^{'}*\left(e^{x}+e^{-x}\right) - \left(e^{x}-e^{-x}\right)*\left(e^{x}+e^{-x}\right)^{'}}{\left(e^{x}+e^{-x}\right)^{2}} =
# \frac{\left(e^{x}+e^{-x}\right)*\left(e^{x}+e^{-x}\right) - \left(e^{x}-e^{-x}\right)*\left(e^{x}-e^{-x}\right)}{\left(e^{x}+e^{-x}\right)^{2}} =
# 1 - \frac{ \left(e^{x}-e^{-x}\right)^{2}}{\left(e^{x}+e^{-x}\right)^{2}}
# $
#
#
# При вычислении были использованы следующие правила дифференцирования:
# (xa)' = $ax^{a-1}$
# $\frac{\left(u\right)}{\left(v\right)}^{'} = \frac{\left(u*v^{'}-u^{'}*v\right)}{v^{2}}$
# $x \in R$, то есть область значений - множество всех действительных чисел.
#
# Теперь найдем область определения: так как  $e^{x}+-e^{-x}<>0$ , то
# $E \in R$, решим уравнение:
#
# $\frac{\left(e^{x}-e^{-x}\right)}{\left(e^{x}+e^{-x}\right)} = 1$
#
# знаменатель положительный всегда
# если x>0, то решение будет стремится к 1 (числитель положительный), если x < 0 то решение будет стремится к -1 (числитель отрицательный).
# Таким образом область определения:(-1,1)
#
#
#  1.4. **ReLU**. $f(x)=\left\{\begin{array}{ll}0 & x<0 \\ x & x \geqslant 0\end{array}\right.$
#
#  $ f^{'}(x) = \left\{\begin{array}{ll}0 & x<0 \\ 1 & x \geqslant 0\end{array}\right.$
#
#  $x \in R$, то есть область значений - множество всех действительных чисел.
#
# Теперь найдем область определения: так как  $f(x)=0$ или $f(x)=x$, то
# $E \in $ [0, +00).
#
#  1.5. **Softplus**. $f(x)=\ln \left(1+e^{x}\right)$
#
#  $ \ (ln\left(1+e^{x}\right))^{'} = \frac{\left(1+e^{x}\right)^{'}}{\left(1+e^{x}\right)} = \frac{e^{x}}{\left(1+e^{x}\right)}
#  $
#  $x \in R$, то есть область значений - множество всех действительных чисел.
#
# Теперь найдем область определения: так как  $f(x)=0$ или $f(x)=x$, то
# $E \in $ [0, +00).
#
#
#  1.6. **Синусоида**. $f(x)=\sin (x)$
#  стандартная производная: $(sin(x))^{'}=cos(x)$
#
# Область значений функции:
#
#  $x \in R$, то есть область значений - множество всех действительных чисел.
#
# Теперь найдем множество значений:
#
# По определению функция $sinus$ имеет предельные минимум равный -1 при $x = -Pi/2$ и максимум равный 1 при $x = Pi/2$, т.к.Область значений функции множество всех действительных чисел, то множество значений будет достигать свои минимумы и максимумы $E \in $ [-1, 1].
#
# 3. Определим моннотонны ли функции
#
# - построим графики функции

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    y = []
    for xi in x:
        y.append(xi)
    return y

a = np.arange(-100, 100)
plt.plot(a, f(a))
plt.title('Identity')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# функция монотонна

# %%
def f(x):
    y = []
    for xi in x:
        if xi >= 0: 
            y.append(1)
        else: 
            y.append(0)
    return y
    
a = np.arange(-100, 100)
plt.plot(a, f(a))
plt.title('Binary step/Единичная ступенька')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# функция монотонна

# %%
def f(x):
    y = []
    for xi in x:
        y.append((np.exp(xi) - np.exp(-xi))/(np.exp(xi) + np.exp(-xi)))
    return y
    
a = np.arange(-100, 100)
plt.plot(a, f(a))
plt.title('Hyperbolic tangent/Гиперболический тангенс')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# функция монотонна

# %%
def f(x):
    y = []
    for xi in x:
        if xi >= 0: 
            y.append(xi)
        else: 
            y.append(0)
    return y
    
a = np.arange(-100, 100)
plt.plot(a, f(a))
plt.title('ReLU')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# функция монотонна

# %%
def f(x):
    y = []
    for xi in x:
        y.append(np.log(1 + np.exp(xi)))
    return y
    
a = np.arange(-100, 100)
plt.plot(a, f(a))
plt.title('Softplus')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# функция монотонна

# %%
def f(x):
    y = []
    for xi in x:
        y.append(np.sin(xi))
    return y
    
a = np.arange(-10,10,0.01)
plt.plot(a, f(a))
plt.title('Синусоида')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# функция не монотонна
